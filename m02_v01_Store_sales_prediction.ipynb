# %% [markdown]
# # Descrição dos Dados com Python

# %% [markdown]
# # **0.0. IMPORTS**

# %%
import pandas as pd

# %%
# !pip install inflection

# %%
import inflection

# %% [markdown]
# ## **0.1. Helper Functions**

# %% [markdown]
# ## **0.2. Loading Data**

# %%
# low_memory=False -> para puxar todo arquivo de uma vez
df_sales_raw = pd.read_csv('/content/drive/My Drive/repos/Data_Science_Em_Producao/data/train.csv', low_memory=False)
df_store_raw = pd.read_csv('/content/drive/My Drive/repos/Data_Science_Em_Producao/data/store.csv', low_memory=False)

# merge
df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')

# %%
# Usar uma linha aleatória usando o método sample() 
# para verificar se carregou os dados corretamente
df_raw.sample()
# Out:
#         Store  DayOfWeek  ... Promo2SinceYear  PromoInterval
# 592034    755          5  ...             NaN            NaN
#
# [1 rows x 18 columns]

# %% [markdown]
# # **1.0. DESCRIÇÃO DOS DADOS**

# %%
# Verificar nome das colunas
df_raw.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %% [markdown]
# ## **1.1. Rename Columns**

# %%
# Fazer uma cópia do dataset para a próxima sessão
df1 = df_raw.copy()

# %%
# Criar uma nova coluna no dataset
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 
            'Promo', 'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
            'CompetitionDistance', 'CompetitionOpenSinceMonth',
            'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
            'Promo2SinceYear', 'PromoInterval']

# Mudar nome das colunas para o tipo snakecase
# usando uma função com lambda da classe inflection e método underscore
snakecase = lambda x: inflection.underscore(x)

# map mapeia a função snakecase em todas as colunas com formato de lista
cols_new = list(map(snakecase, cols_old))

# Fazendo o rename
# Para novo dataset todas colunas irão receber a função
df1.columns = cols_new

# %%
df1.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'customers', 'open', 'promo',
#        'state_holiday', 'school_holiday', 'store_type', 'assortment',
#        'competition_distance', 'competition_open_since_month',
#        'competition_open_since_year', 'promo2', 'promo2_since_week',
#        'promo2_since_year', 'promo_interval'],
#       dtype='object')

# %% [markdown]
# ## **1.2. Data Dimensions**

# %%
# Quantidade de linhas no dataset
print(f'Number of Rows: {df1.shape[0]}')

# Quantidade de linhas no dataset
print(f'Number of Cols: {df1.shape[1]}')
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# ## **1.3. Data Types**

# %%
# Para transformar a coluna date no tipo date
# Use to_datetime(df1['date']) com o dataset e passa a coluna que quer mudar tipo
# pd.to_datetime(df1['date']) pd do pandas
# df1['date'] = pd.to_datetime(df1['date']) e retorna para dentro da coluna date
df1['date'] = pd.to_datetime(df1['date'])

# Verificar os tipos de cada coluna do dataset
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## **1.4. Ckeck NA**

# %%
# df1.isna() mostra se as linhas das colunas tem NA
# df1.isna().sum() mostra a soma de NA em cada coluna
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## **1.1**

# %% [markdown]
# ## **1.1**

# %% [markdown]
# ## **1.1**

# %% [markdown]
# ## **1.1**
